# %%
#Sklearn pipeline

# %%
import pandas as pd
import numpy as np
import seaborn as sns

titanic = sns.load_dataset("titanic")
titanic.head()

df = pd.DataFrame(titanic)
df

#Seperate features
X = df.drop("survived", axis = 1)
y = df['survived']

#Define columns
numerical_features = df[['fare', 'pclass']]
categorical_features = df[['sex', 'who']]

numerical_features.head()
categorical_features.head()
# Out:
#       sex    who
# 0    male    man
# 1  female  woman
# 2  female  woman
# 3  female  woman
# 4    male    man
